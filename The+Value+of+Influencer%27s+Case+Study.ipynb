# %% [markdown]
# # Value of Influencer's Case Study: Porco's Lounge & Tiki Room

# %% [markdown]
# Below I present a case study to concretely illustrate the difference and importance that targeting & acquiring trendy, influential reviewers can have on a businesses growth.
#
# The results here should NOT be interpreted as a precisely accurate measurement of the number of trendy reviewers & influence that a given business experienced. This is because only a small sample all of the businesses reviews & reviewers were included in the original dataset. Therefore, we are only able to visually capture a small sample of the number of trendy users and their level of influence that actually occurred.

# %%
from IPython.display import Image

# %% [markdown]
# ## Porco's Lounge Facts

# %% [markdown]
# Porco's Lounge is a popular business with a 4.5 star average rating on Yelp. We want to identify when Porco's Lounge began trending and how many other friend-reviewers they're pre-trending reviewers influenced to also review Porco's Lounge.

# %%
Image(filename = '/Users/DanielCervoni/Desktop/Porcos.png')

# %% [markdown]
# ---
# ## Porco's Monthly Review Count Time-Series
#
# By looking at Porco's monthly review count time-series, we clearly can see that the business first trended the month it opened, reaching 8 reviews in its first monthly, 12 in its second, and 5 in its third, picking up again after.
#
# Given our measure for defining influence is only concerned with friend's who reviewed the same business within a 2 month period of time, we will only look at reviews that were made in the blue-shaded area. Our pre-trending users in this case are the 8 reviewers who reviewed the business in that first month.

# %%
Image(filename = '/Users/DanielCervoni/Desktop/Porcots.png')

# %% [markdown]
# ---
# ## Porco's Lounge Influencer Network: Base Case
#
# Porco Lounge had 8 trendy users, two of which were actually influential. In a base case, however, we would assume that none of Porco's Lounge's trendy-reviewers didn't actually influence any of their friends to review the business. This would make our network graph look like this:

# %%
Image(filename = '/Users/DanielCervoni/Desktop/porcobase.png')

# %% [markdown]
# ---
# ## Porco's Lounge Influencer Network: Influence Case
#
# However, Porco was able to acquire 2 highly influential reviewers in its pre-trending period, and these 2 reviewers influenced 9 other reviewers to come to Porco's business.

# %%
Image(filename = '/Users/DanielCervoni/Desktop/porcoinf.png')

# %% [markdown]
# ---
# ## Conclusion
#
# By capturing the right trendy, influential reviewers, **Porco’s acquired at the minimum 4.5x the number of new customers and revenues than compared to a baseline, all while significantly decreasing their average customer acquisition cost**.
#
# **By knowing which reviewers are the most influential early adopters (our trendsetters), Yelp now better understands the power they have to help a local business grow quickly, and is able to target these individuals through their advertisements.** This puts themselves and the local businesses in the best position to achieve optimal growth and returns.
